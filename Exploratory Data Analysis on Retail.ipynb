# %%
import numpy as np

# %%
import pandas as pd

# %%
SampleSuperstore_df=pd.read_csv(r"C:\Users\HP\Desktop\Bayo\SparkFoundation\SampleSuperstore.csv")

# %%
SampleSuperstore_df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
SampleSuperstore_df.shape
# Out:
# (9994, 13)

# %%
SampleSuperstore_df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
loss_df=SampleSuperstore_df[SampleSuperstore_df['Profit'] < 0]

# %%
loss_df
# Out:
#            Ship Mode      Segment        Country             City  \
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 14    Standard Class  Home Office  United States       Fort Worth
# 15    Standard Class  Home Office  United States       Fort Worth
# 23      Second Class     Consumer  United States     Philadelphia
# 27    Standard Class     Consumer  United States     Philadelphia
# ...              ...          ...            ...              ...
# 9920  Standard Class    Corporate  United States            Bryan
# 9921  Standard Class  Home Office  United States            Akron
# 9931  Standard Class     Consumer  United States   San Bernardino
# 9937    Second Class    Corporate  United States      Los Angeles
# 9962     First Class  Home Office  United States          Houston
#
#              State  Postal Code   Region         Category Sub-Category  \
# 3          Florida        33311    South        Furniture       Tables
# ...

# %%
loss_df.shape
# Out:
# (1871, 13)

# %%
loss_df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   1871.000000   1871.000000  1871.000000  1871.000000  1871.000000
# mean   55991.122929    250.511574     3.762694     0.480887   -83.448042
# std    26041.501999    715.067296     2.141347     0.235080   284.423422
# min     1841.000000      0.444000     1.000000     0.100000 -6599.978000
# 25%    33024.000000     12.503000     2.000000     0.200000   -58.660950
# 50%    60623.000000     71.088000     3.000000     0.400000   -18.088200
# 75%    77095.000000    284.922000     5.000000     0.700000    -6.261500
# max    98198.000000  22638.480000    14.000000     0.800000    -0.089500

# %%
Total_loss=np.negative(loss_df['Profit'].sum())

# %%
print("Total loss = %.2f" %Total_loss)
# Out:
# Total loss = 156131.29

# %%
loss_df.groupby(by='Segment').sum()
# Out:
#              Postal Code        Sales  Quantity  Discount      Profit
# Segment
# Consumer        57202260  247196.2460      3651    476.76 -84945.7112
# Corporate       30034273  131860.5383      2191    272.00 -44787.2076
# Home Office     17522858   89650.3705      1198    150.98 -26398.3669

# %%
loss_df.groupby(by='Ship Mode').sum()
# Out:
#                 Postal Code        Sales  Quantity  Discount       Profit
# Ship Mode
# First Class        16520799   61560.1024      1102    144.52  -22660.2709
# Same Day            5629672   28460.8410       370     45.95   -8898.1054
# Second Class       16941403   81192.5249      1136    143.05  -24224.3729
# Standard Class     65667517  297493.6865      4432    566.22 -100348.5365

# %%
loss_df.groupby(by='State').sum()
# Out:
#                 Postal Code        Sales  Quantity  Discount      Profit
# State
# Arizona             7247267   14179.0490       354     40.20  -6656.7675
# California          9670931   36530.4460       373     20.15  -3769.6651
# Colorado            5300931   12833.2140       269     34.40  -8900.9048
# Connecticut           12834     252.3570         2      0.60    -19.6146
# Delaware              39610     510.2790         7      0.60    -85.8963
# Florida             4155698   45694.1320       478     63.25  -8689.8295
# Illinois           15479827   38626.2020       948    143.90 -19501.6975
# Maryland              41950     789.8030         5      0.60    -71.1170
# Massachusetts          9796    3275.3210        17      1.50   -566.2617
# Nevada                89031     674.3520         3      0.20   -109.5822
# New Hampshire          3820    1053.1640         4      0.30   -105.3164
# New Jersey            15415     418.2920         4      0.60    -51.2906
# ...

# %%
loss_df.groupby(by='Category').sum()
# Out:
#                  Postal Code        Sales  Quantity  Discount      Profit
# Category
# Furniture           42626448  257885.5868      2652    262.14 -60936.1090
# Office Supplies     48505006   91608.6750      3425    547.20 -56615.2585
# Technology          13627937  119212.8930       963     90.40 -38579.9182

# %%
loss_df.groupby(by='Sub-Category').sum()
# Out:
#               Postal Code        Sales  Quantity  Discount      Profit
# Sub-Category
# Accessories       5286382   10958.8000       330     18.20   -930.6265
# Appliances        4825871    3382.5340       235     53.60  -8629.6412
# Binders          32609300   36140.6130      2456    452.40 -38510.4964
# Bookcases         6423506   48072.7408       422     37.99 -12152.2060
# Chairs           15008025   91988.4560       876     61.40  -9880.8413
# Fasteners          701930     149.2800        55      2.40    -33.1952
# Furnishings      10970913   12845.8440       597     88.60  -6490.9134
# Machines          2236261   72456.2530       157     25.60 -30118.6682
# Phones            6105294   35797.8400       476     46.60  -7530.6235
# Storage           8606475   37869.0720       569     32.20  -6426.3038
# Supplies          1761430   14067.1760       110      6.60  -3015.6219
# Tables           10224004  104978.5460       757     74.15 -32412.1483

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize']=(13,5)

# %%
plt.bar(loss_df['Sub-Category'], loss_df['Sales']);
plt.rcParams.update({'font.size':10});
plt.xlabel('Sub-Category');
plt.ylabel('Sales');

# %%
plt.bar(loss_df['Segment'], loss_df['Sales']);
plt.rcParams.update({'font.size':10});
plt.xlabel('Segment');
plt.ylabel('Sales');

# %%
plt.bar(loss_df['Ship Mode'], loss_df['Sales']);
plt.rcParams.update({'font.size':10});
plt.xlabel('Ship Mode');
plt.ylabel('Sales');

# %%
plt.bar(loss_df['State'], loss_df['Sales']);
plt.rcParams.update({'font.size':15});
plt.xlabel('State');
plt.ylabel('Sales');

# %%
import seaborn as sns

# %%
plt.rcParams['figure.figsize']=(9,5)
sns.countplot(x=SampleSuperstore_df.Segment)
plt.show();

# %%
plt.rcParams.update({'font.size':12})

# %%
plt.rcParams['figure.figsize']=(20,5)
sns.countplot(x='Sub-Category', data=SampleSuperstore_df)
plt.show();

# %%
plt.rcParams['figure.figsize']=(20,5)
sns.countplot(x='Ship Mode', data=SampleSuperstore_df)
plt.show();

# %%
plt.rcParams['figure.figsize']=(20,5)
sns.countplot(x='Region', data=SampleSuperstore_df)
plt.show();

# %%
SampleSuperstore_df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(SampleSuperstore_df.corr(),cmap='Greens',annot=True);
plt.rcParams['figure.figsize']=(10,5)

# %% [markdown]
# From various indications above, it could be established that most of the losses occured as a result of discount given to products of lesser value cost hence the higher purchases of those products resulted in higher loss.
# To correct this, the discount needs to be either taken away or reduced.
